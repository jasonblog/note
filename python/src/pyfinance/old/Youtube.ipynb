# %%
import requests
rs = requests.session()
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'
}
res = rs.get('https://www.youtube.com/watch?v=HrhJxxOLmt4', headers = headers)
#print res.text

# %%
import re
m = re.search('"args":({.*?}),', res.text)

# %%
print m.group(1)
# Out:
# {"dclk":true,"ad_tag":"https:\/\/ad.doubleclick.net\/N4061\/pfadx\/com.ytpwatch.music\/1;kpeid=XR9f4KZpLIvWyyUnMhmbKw;kpid=1;kpu=janetfung1314;kvid=HrhJxxOLmt4;mpvid=X-FlLihkc4O0ZjJX;ord=1297234870;ssl=1;sz=480x360,480x361,480x70;tile=1;afv=1;ciu_szs=300x250,300x60;dc_dbp=ChZqaW1iS1BXRkVaaFluamQtVGJZaWZnEAE;dc_output=xml_vast3;dc_yt=1;dc_yt_pt=APb3F29MQ3RkE4I5PLrQkRz2ikhHa-fPGYlNM6iSBNDqIwOQS9kvV9aLxVKTAkgGIlrbzA8SsZ8UXSphVGq_OQI84K3WNDl2kvMx3xIONmKJnmF9N6Xq6FV_LKN3BkOK3FVjbq7nB8z6vQLAaIJt;k2=3;k2=35;k2=593;k2=1021;k2=1033;k5=3_35_593_1021_1033;kga=-1;kgg=-1;klg=zh-tw;kmyd=watch-longform-ad;ko=c;kr=F;ktype=song,gptc;kvz=205;nlfb=1;yt1st=1;yt3pav=1;ytcat=10;ytdevice=1;ytdevicever=1.20150924;ytexp=9406983;yt_ec=6;yt_ec2=16;yt_vrallowed=1;!c=1","fade_in_start_milliseconds":"-3000","tmi":"1","pltype":"contentugc","fade_in_duration_milliseconds":"1000","ad_slots":"0","innertube_api_key":"AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8","is_listed":"1","dashmpd":"https:\/\/manifest.googlevideo.com
# ...

# %%
import json
jd = json.loads(m.group(1))
print jd.keys()
#print jd["url_encoded_fmt_stream_map"]
#print jd["probe_url"]
# Out:
# [u'is_listed', u'account_playback_token', u'ptk', u'hl', u'tag_for_child_directed', u'adaptive_fmts', u'iurlhq_webp', u'keywords', u'dbp', u'no_get_video_log', u'fmt_list', u'title', u'c', u'dynamic_allocation_ad_tag', u'invideo', u'afv_ad_tag', u'sffb', u'iurlmq_webp', u'cosver', u'watch_xlb', u'apiary_host', u'max_dynamic_allocation_ad_tag_length', u'innertube_api_key', u'timestamp', u'apiary_host_firstparty', u'adsense_video_doc_id', u'innertube_context_client_version', u'mpu', u'ldpj', u'fade_out_duration_milliseconds', u'videostats_playback_base_url', u'idpj', u'avg_rating', u'ad_logging_flag', u'token', u'thumbnail_url', u't', u'ismb', u'dashmpd', u'allow_ratings', u'fexp', u'shortform', u'fflags', u'allow_embed', u'excluded_ads', u'midroll_freqcap', u'enabled_engage_types', u'ad3_module', u'fade_out_start_milliseconds', u'gut_tag', u'length_seconds', u'enablejsapi', u'tmi', u'watermark', u'ad_device', u'fade_in_duration_milliseconds', u'core_dbp', u'atc', u'instream_long', u'o
# ...

# %%
a = 'https://r6---sn-3cu-u2xl.googlevideo.com/videoplayback?upn=L5Y-ppyrzUw&expire=1443344441&lmt=1401187657419923&sparams=clen%2Cdur%2Cgir%2Cid%2Cinitcwndbps%2Cip%2Cipbits%2Citag%2Ckeepalive%2Clmt%2Cmime%2Cmm%2Cmn%2Cms%2Cmv%2Cpl%2Crequiressl%2Csource%2Cupn%2Cexpire&clen=7712428&source=youtube&ms=au&mv=m&fexp=3300132%2C3300137%2C3300161%2C3310698%2C3312381%2C9405264%2C9408548%2C9408710%2C9409069%2C9412839%2C9413122%2C9413137%2C9414930%2C9415365%2C9415485%2C9416023%2C9416126%2C9416838%2C9417707%2C9418096%2C9418153%2C9418204%2C9418401%2C9418448%2C9418751%2C9419400%2C9419444%2C9420078%2C9420348%2C9421013%2C9421250&mt=1443322781&dur=281.114&id=o-AE8G1t0EJhTQlvvbcO123Q-5CAsW1U6ZX3lEMOaltpzd&mn=sn-3cu-u2xl&mm=31&gir=yes&sver=3&mime=video%2Fwebm&requiressl=yes&itag=243&keepalive=yes&ip=115.43.60.101&pl=19&initcwndbps=1871250&ipbits=0&key=yt6&cpn=Ec2TJmM30h9qbhrZ&alr=yes&ratebypass=yes&signature=39A2C283703DAA318AF6DBCAE4DC68B9F973E4F0.394E78532049B132A69078C0C7DF22B6A51F90EE&c=WEB&cver=html5&range=0-72962&rn=1&rbuf=0'
res2 = rs.get(a, stream=True)
f = open('c2.mp4', 'wb')
shutil.copyfileobj(res2.raw, f)
f.close()

# %%
import urlparse
stream_map = urlparse.parse_qs(jd["url_encoded_fmt_stream_map"])
print stream_map["s"][0]
#print a
# Out:
# 7D4DA5DF4DB1DF75BD54F391442E6AF9F91045DF23.ACFAFD1E9FDD37FECB4DE406F5661998C1B506E5

# %%
print a['probe_url']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-2be3078236b0> in <module>()
# ----> 1 print a['probe_url']
#
# KeyError: 'probe_url'

# %%
print a['url'][0]
import shutil
for idx,link in enumerate(a['url']):
    print link + "&signature=" + stream_map["s"][0]
    res2 = rs.get(link + "&signature=" + stream_map["s"][0], stream=True)
    f = open('%s.mp4'%(idx), 'wb')
    shutil.copyfileobj(res2.raw, f)
    f.close()
# Out:
# https://r6---sn-3cu-u2xl.googlevideo.com/videoplayback?ms=au&mt=1443322478&mv=m&dur=0.000&sver=3&itag=43&key=yt6&mn=sn-3cu-u2xl&id=o-ADuXlyPE3aKMvFDFgAAOwpsLgUhFG3ys2UlYwgMNa431&expire=1443344136&mm=31&ip=115.43.60.101&lmt=1297579068687556&source=youtube&sparams=dur%2Cid%2Cinitcwndbps%2Cip%2Cipbits%2Citag%2Clmt%2Cmime%2Cmm%2Cmn%2Cms%2Cmv%2Cpl%2Cratebypass%2Crequiressl%2Csource%2Cupn%2Cexpire&initcwndbps=2012500&pl=19&fexp=9406983%2C9408710%2C9409069%2C9415365%2C9415485%2C9416023%2C9416126%2C9417707%2C9418153%2C9418448%2C9420348%2C9421013&upn=kK4nvd2O7GY&ipbits=0&mime=video%2Fwebm&ratebypass=yes&requiressl=yes
# ...

# %%
# Out:
# ó2cluIü½ å¤)Üh]=6H~
