# %%
import urllib.request
import os
import tarfile

# %%
url="http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
filepath="data/aclImdb_v1.tar.gz"
if not os.path.isfile(filepath):
    result=urllib.request.urlretrieve(url,filepath)
    print('downloaded:',result)
# Out:
# downloaded: ('data/aclImdb_v1.tar.gz', <http.client.HTTPMessage object at 0x00000256F5C98DD8>)

# %%
if not os.path.exists("data/aclImdb"):
    tfile = tarfile.open("data/aclImdb_v1.tar.gz", 'r:gz')
    result=tfile.extractall('data/')

# %% [markdown]
# # 1. Import Library

# %%
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 資料準備

# %%
#讀取檔案

# %%
import re
def rm_tags(text):
    re_tag = re.compile(r'<[^>]+>')
    return re_tag.sub('', text)

# %%
import os
def read_files(filetype):
    path = "data/aclImdb/"
    file_list=[]

    positive_path=path + filetype+"/pos/"
    for f in os.listdir(positive_path):
        file_list+=[positive_path+f]
    
    negative_path=path + filetype+"/neg/"
    for f in os.listdir(negative_path):
        file_list+=[negative_path+f]
        
    print('read',filetype, 'files:',len(file_list))
       
    all_labels = ([1] * 12500 + [0] * 12500) 
    
    all_texts  = []
    for fi in file_list:
        with open(fi,encoding='utf8') as file_input:
            all_texts += [rm_tags(" ".join(file_input.readlines()))]
            
    return all_labels,all_texts

# %%
y_train,train_text=read_files("train")
# Out:
# read train files: 25000

# %%
y_test,test_text=read_files("test")
# Out:
# read test files: 25000

# %%
#查看正面評價的影評

# %%
train_text[0]
# Out:
# 'Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High\'s satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers\' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I\'m here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn\'t!'

# %%
y_train[0]
# Out:
# 1

# %%
#查看負面評價的影評

# %%
train_text[12499]
# Out:
# 'Working-class romantic drama from director Martin Ritt is as unbelievable as they come, yet there are moments of pleasure due mostly to the charisma of stars Jane Fonda and Robert De Niro (both terrific). She\'s a widow who can\'t move on, he\'s illiterate and a closet-inventor--you can probably guess the rest. Adaptation of Pat Barker\'s novel "Union Street" (a better title!) is so laid-back it verges on bland, and the film\'s editing is a mess, but it\'s still pleasant; a rosy-hued blue-collar fantasy. There are no overtures to serious issues (even the illiteracy angle is just a plot-tool for the ensuing love story) and no real fireworks, though the characters are intentionally a bit colorless and the leads are toned down to an interesting degree. The finale is pure fluff--and cynics will find it difficult to swallow--though these two characters deserve a happy ending and the picture wouldn\'t really be satisfying any other way. *** from ****'

# %%
y_train[12499]
# Out:
# 1

# %% [markdown]
# # 先讀取所有文章建立字典，限制字典的數量為nb_words=2000

# %%
token = Tokenizer(num_words=2000)
token.fit_on_texts(train_text)

# %%
#Tokenizer屬性

# %%
#fit_on_texts 讀取多少文章

# %%
print(token.document_count)
# Out:
# 25000

# %%
print(token.word_index)
# Out:
# {'\x91arabella': 52033, 'reedus': 52034, "marvin's": 30559, 'farcry': 52035, 'paraphrased': 30560, 'jellies': 52036, "'anywhere": 52037, 'mccay': 40827, "suzanne's": 40828, 'clin': 52038, 'pont': 77781, 'midas': 40829, 'deerhunter': 30561, 'animates': 27211, 'enchanting': 7472, 'electrifyingly': 34692, "othello's": 27619, 'hermes': 34693, 'aragon': 40830, 'backside': 17627, 'hovis': 40831, 'frees': 21890, 'outfits': 5395, 'battlefield': 7911, 'schoolkids': 76926, 'dept': 18506, 'mortadello': 52041, 'themselfs': 52042, 'heron': 40832, 'conceptionless': 52043, 'registers': 20589, "grammar's": 52044, 'extent': 2820, 'fracturing': 52045, 'stinger': 52046, 'glow': 8769, 'grubach': 52047, 'buffalos': 52048, 'suceed': 52049, "virgins'": 52050, 'boatworkers': 52051, 'resonant': 19496, '92': 19494, 'vangard': 52053, 'astrotheology': 52054, 'lao': 40833, 'qualifies': 8166, 'meaningless': 4007, 'pardon': 11575, 'chipping': 27620, 'hobbyhorse': 52055, 'spinner': 40834, 'clandestinely': 40835, "oliver'": 52056, 'friedrich': 40836, 'feebly': 30562, 'slammer': 27621, 'whih': 52057, 'ev': 52058, "howl's": 27622, 'klara': 21891, 'lodging': 30563, 'precursors': 40837, 'laborers': 30564, 'gosha': 16110, "'twilight": 52059, 'pinkus': 52060, 'withdrawal': 24940, 'pontificating': 21892, 'chapters': 9456, 'dewames': 52062, 'prosecute': 30565, 'nourishing': 52063, 'porsche': 15485, 'studio': 1176, 'elegantly': 14357, "character'": 35308, 'wanking': 40838, 'roy': 2357, 'gilchrist': 24941, 'condieff': 34694, 'propagandic': 68529, 'backula': 33999, 'respiration': 52065, 'synthed': 52066, 'unfaithful': 10775, 'weapons': 2861, "90's": 3080, 'washburn': 30566, "yanos'": 52067, 'caroll': 52068, 'familymembers': 52069, "maradona's": 52070, "baywatch'": 52071, "'hi": 40895, 'sabbato': 52073, 'cooperate': 16111, 'highs': 16810, "beaver's": 52074, 'gower': 52075, 'came': 381, 'drycoff': 52076, 'sweets': 12995, 'expected': 868, 'boons': 52077, "prosero's": 52078, 'luckiest': 34695, 'condolences': 34696, 'coilition': 52079, 'symphonies': 52080, 'waded': 52081, 'cécile': 34697, 'bumbling': 4838, 'kp': 52082, 'yearly': 19495, 'manufacturing': 21893, 'zealander': 30567, 'mind': 326, 'frider': 52083, 'diwanireview': 52084, 'pym': 12996, 'pervert': 10549, 'mountian': 52085, 'hasslehoff': 40839, 'exception': 1392, 'deriving': 34698, 'corrects': 40840, 'meso': 25240, 'gwot': 89574, "o'bannon's": 54756, "'pinball": 52086, 'rosetta': 17628, 'wished': 4445, 'wishi': 52087, 'bantha': 40841, 'goines': 15882, "aiken's": 40842, 'latinamerica': 52089, 'underachievers': 52090, 'duh': 7473, "usc's": 70675, 'radcliffe': 40844, 'urinary': 52091, "dreamers'": 52092, 'gayest': 34735, 'modify': 30568, 'molden': 52094, 'lister': 23368, '1860s': 52095, "'owning": 52096, 'dateless': 40845, 'sobbing': 15486, 'enunciation': 40846, 'mcqueen': 6788, 'fated': 10550, 'strategy': 11923, 'tied': 3127, 'tidbits': 21894, 'deputize': 52098, 'bloodwaters': 52099, 'headaches': 18871, 'unglued': 52100, 'kristoferson': 40847, 'parasite': 16112, 'paunchy': 52101, 'kittson': 52102, 'overdeveloped': 40848, 'manifest': 16115, 'contempory': 52104, "bryson's": 34699, 'glamorously': 40849, 'dances': 4173, 'sentient': 52105, 'mismanagement': 40850, 'inhabitant': 20590, 'shlater': 52106, '300lbs': 52107, 'anymore': 1624, 'distribution': 4986, 'tombs': 25241, '4°c': 52108, 'deardon': 52109, 'pyrotechnics': 16811, 'accelerant': 52110, "'distorted'": 52111, 'lasers': 27749, 'drago': 21801, 'majestic': 11032, 'evs': 52112, "''human''": 52113, 'imploringly': 52114, 'lew': 18507, 'troyes': 52115, "'some": 27623, 'slav': 52116, "'hamilton": 52117, 'interestingly': 5670, 'kidalso': 52118, "lordi's": 34700, 'setembro': 52119, "'sound": 52120, 'belying': 40852, 'd8': 52121, 'dangle': 52122, 'bonecrushing': 52123, "aumont's": 52124, "sands's": 52125, 'lighted': 11924, 'shocker': 8284, 'goriness': 52126, 'keystone': 12256, "aames's": 52127, 'enriching': 25242, 'films\x85\x85': 52129, 'castleville': 40853, "hobson's": 52130 ...

# %% [markdown]
# # 將每一篇文章的文字轉換一連串的數字
# #只有在字典中的文字會轉換為數字

# %%
x_train_seq = token.texts_to_sequences(train_text)
x_test_seq  = token.texts_to_sequences(test_text)

# %%
print(train_text[0])
# Out:
# Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I'm here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!

# %%
print(x_train_seq[0])
# Out:
# [308, 6, 3, 1068, 208, 8, 29, 1, 168, 54, 13, 45, 81, 40, 391, 109, 137, 13, 57, 149, 7, 1, 482, 68, 5, 261, 11, 6, 72, 5, 631, 70, 6, 1, 5, 1, 1534, 33, 66, 63, 204, 139, 64, 1229, 1, 4, 1, 222, 900, 28, 68, 4, 1, 9, 693, 2, 64, 1534, 50, 9, 215, 1, 386, 7, 59, 3, 1471, 799, 5, 176, 1, 391, 9, 1235, 29, 308, 3, 352, 343, 142, 129, 5, 27, 4, 125, 1471, 5, 308, 9, 532, 11, 107, 1469, 4, 57, 555, 100, 11, 308, 6, 226, 47, 3, 11, 8, 214]

# %% [markdown]
# # 讓轉換後的數字長度相同

# %%
#
#文章內的文字，轉換為數字後，每一篇的文章地所產生的數字長度都不同，因為後需要進行類神經網路的訓練，所以每一篇文章所產生的數字長度必須相同
#以下列程式碼為例maxlen=100，所以每一篇文章轉換為數字都必須為100
#bj6eji3t03g/ 2k

# %%
x_train = sequence.pad_sequences(x_train_seq, maxlen=100)
x_test  = sequence.pad_sequences(x_test_seq,  maxlen=100)

# %%
#如果文章轉成數字大於0,pad_sequences處理後，會truncate前面的數字

# %%
print('before pad_sequences length=',len(x_train_seq[0]))
print(x_train_seq[0])
# Out:
# before pad_sequences length= 106
# [308, 6, 3, 1068, 208, 8, 29, 1, 168, 54, 13, 45, 81, 40, 391, 109, 137, 13, 57, 149, 7, 1, 482, 68, 5, 261, 11, 6, 72, 5, 631, 70, 6, 1, 5, 1, 1534, 33, 66, 63, 204, 139, 64, 1229, 1, 4, 1, 222, 900, 28, 68, 4, 1, 9, 693, 2, 64, 1534, 50, 9, 215, 1, 386, 7, 59, 3, 1471, 799, 5, 176, 1, 391, 9, 1235, 29, 308, 3, 352, 343, 142, 129, 5, 27, 4, 125, 1471, 5, 308, 9, 532, 11, 107, 1469, 4, 57, 555, 100, 11, 308, 6, 226, 47, 3, 11, 8, 214]

# %%
print('after pad_sequences length=',len(x_train[0]))
print(x_train[0])
# Out:
# after pad_sequences length= 100
# [  29    1  168   54   13   45   81   40  391  109  137   13   57  149    7
#     1  482   68    5  261   11    6   72    5  631   70    6    1    5    1
#  1534   33   66   63  204  139   64 1229    1    4    1  222  900   28   68
#     4    1    9  693    2   64 1534   50    9  215    1  386    7   59    3
#  1471  799    5  176    1  391    9 1235   29  308    3  352  343  142  129
#     5   27    4  125 1471    5  308    9  532   11  107 1469    4   57  555
#   100   11  308    6  226   47    3   11    8  214]

# %%
#如果文章轉成數字不足100,pad_sequences處理後，前面會加上0

# %%
print('before pad_sequences length=',len(x_train_seq[1]))
print(x_train_seq[1])
# Out:
# before pad_sequences length= 335
# [38, 13, 739, 43, 73, 31, 1829, 14, 149, 17, 111, 3, 1338, 5, 335, 144, 19, 1, 886, 11, 67, 276, 1190, 402, 33, 118, 282, 35, 166, 5, 391, 153, 38, 14, 1, 547, 87, 80, 100, 4, 1, 13, 39, 3, 412, 1201, 133, 40, 179, 137, 13, 1, 321, 19, 358, 5, 1, 38, 44, 25, 372, 5, 126, 52, 19, 1, 1982, 17, 47, 44, 21, 67, 344, 3, 5, 408, 19, 1, 1982, 14, 3, 205, 1, 21, 276, 65, 35, 3, 340, 1, 719, 727, 3, 1267, 19, 1, 1507, 3, 1224, 2, 282, 21, 276, 5, 63, 47, 41, 36, 5, 25, 11, 6, 33, 33, 379, 13, 295, 3, 1022, 128, 33, 43, 282, 7, 1, 178, 362, 5, 93, 3, 15, 3, 5, 63, 44, 26, 66, 408, 7, 1, 1982, 14, 499, 205, 1, 44, 26, 66, 78, 47, 26, 490, 15, 3, 701, 1184, 4, 227, 49, 1, 19, 117, 6, 1371, 19, 1, 886, 15, 3, 19, 23, 5, 23, 171, 844, 117, 26, 187, 1484, 121, 1, 236, 344, 1, 30, 3, 99, 41, 394, 19, 23, 117, 888, 81, 101, 582, 3, 251, 30, 1, 400, 4, 1959, 31, 1230, 33, 184, 154, 37, 340, 2, 37, 2, 33, 22, 454, 338, 5, 1, 1982, 502, 214, 236, 20, 338, 5, 36, 26, 276, 118, 50, 108, 1022, 117, 41, 544, 38, 511, 38, 25, 552, 133, 1, 115, 196, 2, 281, 1662, 5, 110, 9, 254, 109, 5, 25, 27, 4, 104, 117, 5, 108, 3, 208, 8, 283, 3, 495, 1076, 5, 23, 153, 137, 13, 181, 38, 14, 1, 547, 5, 119, 47, 41, 36, 256, 138, 154, 8, 1, 372, 247, 38, 19, 1, 81, 503, 227, 3, 375, 36, 28, 1022, 80, 78, 50, 32, 88, 120, 47, 5, 78, 15, 64, 274, 275, 32, 140, 198, 8, 5, 1, 300, 4, 767, 8, 36, 274, 38, 275, 10, 18, 76, 21, 5, 335, 404]

# %%
print('after pad_sequences length=',len(x_train[1]))
print(x_train[1])
# Out:
# after pad_sequences length= 100
# [ 544   38  511   38   25  552  133    1  115  196    2  281 1662    5  110
#     9  254  109    5   25   27    4  104  117    5  108    3  208    8  283
#     3  495 1076    5   23  153  137   13  181   38   14    1  547    5  119
#    47   41   36  256  138  154    8    1  372  247   38   19    1   81  503
#   227    3  375   36   28 1022   80   78   50   32   88  120   47    5   78
#    15   64  274  275   32  140  198    8    5    1  300    4  767    8   36
#   274   38  275   10   18   76   21    5  335  404]

# %% [markdown]
# # 資料預處理

# %%
token = Tokenizer(num_words=2000)
token.fit_on_texts(train_text)

# %%
x_train_seq = token.texts_to_sequences(train_text)
x_test_seq  = token.texts_to_sequences(test_text)

# %%
x_train = sequence.pad_sequences(x_train_seq, maxlen=100)
x_test  = sequence.pad_sequences(x_test_seq,  maxlen=100)
